# %%
import os
import test
import time
import bs4
from bs4 import BeautifulSoup
# print("Hello")
# print(dir(test))
# print(help(test))
# print()
help('modules')
# with open('modules.txt','w') as fd:
    # fd.write(str(hlp))
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# Cread_multi_dir     bleach              marshal             sspicon
# IPython             bs4                 math                stack_data
# PIL                 builtins            matplotlib          start_pythonwin
# Scan_dir            bz2                 matplotlib_inline   stat
# __future__          cProfile            mimetypes           statistics
# __hello__           calendar            mistune             string
# __phello__          certifi             mmap                stringprep
# _abc                cffi                mmapfile            struct
# _aix_support        cgi                 mmsystem            subprocess
# _argon2_cffi_bindings cgitb               modulefinder        sunau
# _ast                charset_normalizer  mpl_toolkits        symtable
# _asyncio            chunk               msilib              sys
# _bisect             climate_change      msvcrt              sysconfig
# ...
