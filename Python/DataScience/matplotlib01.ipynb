# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# print(help())
# print(help(np.arange))
x = np.arange(1,10,1)
# y = np.arange(21,40,2)
y = x**3
z = x**2
# print("array: ", arr)
fig = plt.figure()
aix = fig.add_subplot()
aix.plot(x,y,label="Cube")
aix.plot(x,z,label='Square')
plt.legend(loc='best')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
marks = [90,81,53,64,75]
student = []
plt.pie(x)
plt.show()
