# %%
import numpy as np
# print(dir(np))
with open('np_modules_feature.txt', 'w') as npfd:
    for item in dir(np):
        npfd.write(item+'\n')

# %%
import numpy as np
arr = np.array([i for i in range(1,11)])
print(np.max(arr))
print(np.version)
# Out:
# 10
# <module 'numpy.version' from 'C:\\Program Files\\Python311\\Lib\\site-packages\\numpy\\version.py'>

# %%
import numpy as np
# print(help(np.linspace))

# %%
import numpy as np
import matplotlib.pyplot as plt
# linspace(start, stop, num=50, endpoint=True, retstep=False, dtype=None, axis=0)
# arr = np.linspace(1,10,endpoint=True, dtype=np.uint32)
# print("arr = ", arr)
# # 
# arr1 = np.linspace(1,10,endpoint=False,dtype=np.uint32)
# print("arr1 = ", arr1)
# arr2 = np.linspace(1,10, num=30, endpoint=True)
arr2 = np.linspace(1,10, num=30, endpoint=False)
idx = [i for i in range(len(arr2)-19)]
# print(arr2)
# arr3 = np.linspace(1,15, num=30, endpoint=False)
arr3 = arr2**3
arr4 = np.linspace(10,1,num=30, endpoint=False)
arr5 = arr4**3
# print(arr3)
fig, (ax1,ax2) = plt.subplots(nrows=1,ncols=2, figsize=(15,5))
ax1.plot(arr2, arr3, '--', label='Y')
ax2.plot(arr5, arr4, '*')
# print(plt.fi)
# plt.plot(arr2, arr3)
# plt.plot(arr5,arr4)
# plt.xticks(idx)
ax1.set_xlabel("X-Axis")
ax1.set_ylabel("Y-Axis: X^3")
ax2.set_xlabel("X-Axis: Y^3")
ax2.set_ylabel("Y-Axis")
ax1.set_title("Graph of X^3")
ax2.set_title("Graph of X^-3")
ax1.legend()
ax1.grid(True)
ax2.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# plt.plot()
fig = plt.figure()
ax1 = fig.add_subplot()
arr1 = np.linspace(1,10,num=20,endpoint=False)
colrs = [i for i in range(len(arr1))]
ax1.plot(arr1, arr1**2)
fig1 = plt.figure()
ax2 = fig1.add_subplot()
ax2.plot(arr1**2, arr1**3)
# matplotlib.pyplot.colorbar(mappable=None, cax=None, ax=None, **kwargs)
# plt.colorbar(colrs)
plt.show()

# %%
# Python Program illustrating 
# pyplot.colorbar() method 
import numpy as np 
import matplotlib.pyplot as plt 

# Dataset 
# List of total number of items purchased 
# from each products 
purchaseCount = [100, 200, 150, 23, 30, 50, 
				156, 32, 67, 89] 

# List of total likes of 10 products 
likes = [50, 70, 100, 10, 10, 34, 56, 18, 35, 45] 

# List of Like/Dislike ratio of 10 products 
ratio = [1, 0.53, 2, 0.76, 0.5, 2.125, 0.56, 
		1.28, 1.09, 1.02] 

# scatterplot 
plt.scatter(x=purchaseCount, y=likes, c=ratio, cmap="summer") 

plt.colorbar(label="Like/Dislike Ratio", orientation="horizontal") 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create some example data (you can replace this with your actual data)
data = np.random.rand(10, 10)

# Create a heatmap (or any other plot)
plt.imshow(data, cmap='viridis')

# Add a colorbar
cbar = plt.colorbar()

# Set the label for the colorbar
cbar.set_label('Your Label Here', fontsize=12)

# Show the plot
# shift+tab
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
print(np.NaN)
arr = pd.Series([1,2,3,4,np.NaN,5])
print(arr)
plt.plot(arr)
plt.show()
# Out:
# nan
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    NaN
# 5    5.0
# dtype: float64

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
