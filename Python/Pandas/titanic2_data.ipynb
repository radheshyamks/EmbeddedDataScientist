# %%
import pandas as pd;
import numpy as np
# pd.set_option('display.max_rows', None)
df = pd.read_csv(r"E:\NotepadPlusPlus\CSV\train.csv")
# print(df)

# %%
import pandas as pd;
import numpy as np
df = pd.read_csv(r"E:\NotepadPlusPlus\CSV\train.csv")
print(df.isnull())
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# 5          False     False   False  False  False   True  False  False   False
# 6          False     False   False  False  False  False  False  False   False
# 7          False     False   False  False  False  False  False  False   False
# 8          False     False   False  False  False  False  False  False   False
# 9          False     False   False  False  False  False  False  False   False
# 10         False     False   False  False  False  False  False  False   False
# ...

# %%
import numpy as np;
import pandas as pd
df = pd.read_csv(r"E:\NotepadPlusPlus\CSV\train.csv")
print(df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
import numpy as np
import pandas as np
import math
df = pd.read_csv(r"E:\NotepadPlusPlus\CSV\train.csv")
print(df['Age'].describe())
print(df['Age'].mean())
MeanAge = math.ceil(df['Age'].mean())
print("MeanAge = ",MeanAge)
df['Age'].fillna(value=MeanAge,inplace=True)
print(df['Age'].isnull().sum())
print(df.isnull().sum())
df.to_csv(r"E:\NotepadPlusPlus\CSV\modified_train.csv",index=False)
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64
# 29.69911764705882
# MeanAge =  30
# 0
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
import pandas as pd
import numpy as np
import random
import string
df = pd.read_csv(r"E:\NotepadPlusPlus\CSV\train.csv")
# print(df['Cabin'])
# print(df['Cabin'].isnull())
# print(np.random.randint(100, size=(1)))
# print(np.random.randint(100))
# print(random.choice(string.ascii_lowercase))
# p = random.choice(string.ascii_uppercase)+str(np.random.randint(100))+str(np.random.randint(100))
df['Cabin'].fillna(value = random.choice(string.ascii_uppercase)+str(np.random.randint(100))+str(np.random.randint(100)), inplace=True)
# print(p)
df.to_csv(r"E:\NotepadPlusPlus\CSV\modified_train1.csv",index=False)
# print(df['Cabin'].isnull().sum())

# %%
import pandas as pd
import numpy as np
df = pd.read_csv(r"E:\NotepadPlusPlus\CSV\modified_train1.csv")
print(df.isnull().sum())
MeanAge = np.ceil(df['Age'].mean())
df['Age'].fillna(value=MeanAge,inplace=True)
df.to_csv(r"E:\NotepadPlusPlus\CSV\modified_train2.csv",index=False)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin            0
# Embarked         2
# dtype: int64

# %%
import pandas as pd
import numpy as np
import string
import random
df = pd.read_csv(r"E:\NotepadPlusPlus\CSV\modified_train2.csv")
print(df.isnull().sum())
print(string.ascii_uppercase)
print(random.choice(string.ascii_uppercase))
df['Embarked'].fillna(value = random.choice(string.ascii_uppercase), inplace=True)
df.to_csv(r"E:\NotepadPlusPlus\CSV\modified_train3.csv",index=False)
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64
# ABCDEFGHIJKLMNOPQRSTUVWXYZ
# K

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import string
import random
df = pd.read_csv(r"E:\NotepadPlusPlus\CSV\modified_train3.csv")
print(df.isnull().sum())
plt.plot(df['Age'])
plt.show()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import string
import random
df = pd.read_csv(r"E:\NotepadPlusPlus\CSV\modified_train3.csv")
plt.plot(df['Sex'])
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import string
import random
df = pd.read_csv(r"E:\NotepadPlusPlus\CSV\modified_train3.csv")
print(df.describe().mean())
plt.plot('Survived')
plt.show()
# Out:
# PassengerId    478.044230
# Survived       111.733804
# Pclass         113.268089
# Age            137.647682
# SibSp          112.703219
# Parch          112.273456
# Fare           192.323930
# dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import string
df = pd.read_csv(r"E:\NotepadPlusPlus\CSV\modified_train3.csv")
font1 = {'family':'serif', 'color':'blue', 'size':20}
print(df.isnull().sum())
plt.plot(df['Ticket'])
plt.xlabel('People')
plt.ylabel("Ticket Id's", fontdict = font1)
plt.title("Titanic ticket Analysis", fontdict=font1, loc='center')
plt.show()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import string
df = pd.read_csv(r"E:\NotepadPlusPlus\CSV\modified_train3.csv")
font1 = {'family':'serif', 'color':'blue', 'size':20}
plt.plot(df['Ticket'])
plt.title("Titanic Ticket Analysis", fontdict=font1, loc = 'left')
plt.xlabel("No. of People", fontdict = font1)
plt.ylabel("Ticket Id's", fontdict = font1)
# plt.grid()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import string
import random
df = pd.read_csv(r"E:\NotepadPlusPlus\CSV\modified_train3.csv")
plt.plot(df['Ticket'])
plt.subplot(1,2,2)
# df['Survived']
plt.show()
# Out:
# C:\Users\radhe\AppData\Local\Temp\ipykernel_13864\998016715.py:8: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,2)
